# %% [markdown]
# ### _**Name: Hafiza Fatima Sabir**_
# ### _**Roll no: SU92-BSAI-F24-116**_
# ### _**Lab task - 07**_

# %%
class Graph:
    def __init__(self, adjacency_list):
        self.adjacency_list = adjacency_list

    def get_neighbors(self, node):
        return self.adjacency_list.get(node, [])

    def heuristic(self, node):
        H = {
            'A': 1,
            'B': 1,
            'C': 1,
            'D': 1
        }
        return H[node]

    def a_star(self, start, goal):
        open_set = set([start])

        closed_set = set()

        g_score = {start: 0}

        parent = {start: start}

        while open_set:
            current = None
            for node in open_set:
                if current is None or g_score[node] + self.heuristic(node) < g_score[current] + self.heuristic(current):
                    current = node

            if current is None:
                print("No path exists!")
                return None

            if current == goal:
                path = []
                while parent[current] != current:
                    path.append(current)
                    current = parent[current]
                path.append(start)
                path.reverse()

                print("Shortest Path Found:", path)
                return path

            for neighbor, weight in self.get_neighbors(current):
                cost = g_score[current] + weight

                if neighbor not in g_score or cost < g_score[neighbor]:
                    g_score[neighbor] = cost
                    parent[neighbor] = current
                    open_set.add(neighbor)

            open_set.remove(current)
            closed_set.add(current)

        print("No path exists!")
        return None

adjacency_list = {
    'A': [('B', 1), ('C', 3), ('D', 7)],
    'B': [('D', 5)],
    'C': [('D', 12)],
    'D': []  
}

graph = Graph(adjacency_list)

graph.a_star('A', 'D')
# Out:
# Shortest Path Found: ['A', 'B', 'D']
# ['A', 'B', 'D']
